# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/amandeepdutta13/India-s-Ground-Water-Quality/main/Ground%20Water%202016.csv")

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df.head()
# Out:
#    Station Code                                       Station Name  \
# 0          26.0                                  WELL AT VIJAYWADA
# 1        1513.0  BORE WELL. - KRISHNA MURTHY, D.NO. 48-16-43\nA...
# 2        1514.0  BORE WELL - VIJAY KUMAR AUTONAGAR\nVIJAYAWADA,...
# 3        1516.0                BORE WELL OF NAVLOK GARDENS NELLORE
# 4        1517.0        BORE WELL. - TUNGBHADRA RIVER NEAR\nKURNOOL
#
#             STATE  Temperature Min  Temperature Max  pH Min  pH Max  \
# 0  ANDHRA PRADESH             22.0             26.0    7.51    8.03
# 1  ANDHRA PRADESH             23.0             26.0    7.70    8.00
# 2  ANDHRA PRADESH             23.0             23.0    7.40    8.00
# 3  ANDHRA PRADESH              NaN              NaN    8.50    8.60
# 4  ANDHRA PRADESH             23.0             29.0    7.60    7.90
#
#    Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 0                        960.0                       1418.0  2016
# ...

# %%
df.isnull().sum()
# Out:
# Station Code                    8
# Station Name                    0
# STATE                           8
# Temperature Min                42
# Temperature Max                42
# pH Min                          9
# pH Max                          9
# Conductivity (µmhos/cm) Min    13
# Conductivity (µmhos/cm) Max    13
# Year                            0
# dtype: int64

# %%
df['pH Max'].dtype
# Out:
# dtype('float64')

# %%
df['pH Max'] = pd.to_numeric(df['pH Max'], errors='coerce')

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Create a linear regression model
model = LinearRegression()

# %%
df.head()
# Out:
#    Station Code                                       Station Name  \
# 0          26.0                                  WELL AT VIJAYWADA
# 1        1513.0  BORE WELL. - KRISHNA MURTHY, D.NO. 48-16-43\nA...
# 2        1514.0  BORE WELL - VIJAY KUMAR AUTONAGAR\nVIJAYAWADA,...
# 3        1516.0                BORE WELL OF NAVLOK GARDENS NELLORE
# 4        1517.0        BORE WELL. - TUNGBHADRA RIVER NEAR\nKURNOOL
#
#             STATE  Temperature Min  Temperature Max  pH Min  pH Max  \
# 0  ANDHRA PRADESH             22.0             26.0    7.51    8.03
# 1  ANDHRA PRADESH             23.0             26.0    7.70    8.00
# 2  ANDHRA PRADESH             23.0             23.0    7.40    8.00
# 3  ANDHRA PRADESH              NaN              NaN    8.50    8.60
# 4  ANDHRA PRADESH             23.0             29.0    7.60    7.90
#
#    Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 0                        960.0                       1418.0  2016
# ...

# %%
df.drop(["Station Name","STATE","Temperature Min","Temperature Max","pH Min"],axis=1)
# Out:
#      Station Code  pH Max  Conductivity (µmhos/cm) Min  \
# 0            26.0    8.03                        960.0
# 1          1513.0    8.00                       1214.0
# 2          1514.0    8.00                       1010.0
# 3          1516.0    8.60                        557.0
# 4          1517.0    7.90                       4060.0
# ..            ...     ...                          ...
# 668        1602.0    7.40                       1422.0
# 669        1603.0    7.20                       3570.0
# 670        1604.0    7.20                       4999.0
# 671        1605.0    7.40                       1250.0
# 672        1606.0    7.30                        740.0
#
#      Conductivity (µmhos/cm) Max  Year
# 0                         1418.0  2016
# 1                         1260.0  2016
# 2                         1427.0  2016
# 3                          670.0  2016
# 4                         4220.0  2016
# ..                           ...   ...
# ...

# %%
df.dropna()
# Out:
#      Station Code                                       Station Name  \
# 0            26.0                                  WELL AT VIJAYWADA
# 1          1513.0  BORE WELL. - KRISHNA MURTHY, D.NO. 48-16-43\nA...
# 2          1514.0  BORE WELL - VIJAY KUMAR AUTONAGAR\nVIJAYAWADA,...
# 4          1517.0        BORE WELL. - TUNGBHADRA RIVER NEAR\nKURNOOL
# 5          1518.0                 BORE WELL. - NANDYAL, KURNOOL DIST
# ..            ...                                                ...
# 668        1602.0                               WELL C/O GOVT. PRESS
# 669        1603.0                      WELL C/O OLD POLICE\nBARRACKS
# 670        1604.0                             WELL C/O MPSAF QUARTER
# 671        1605.0                                  WELL NEAR HALIPAD
# 672        1606.0                   PUBLIC WELL OPPOSITE\nS.B.SCHOOL
#
#               STATE  Temperature Min  Temperature Max  pH Min  pH Max  \
# ...

# %%
k=df.drop(["Station Name","STATE"],axis=1)

# %%
print(model)
# Out:
# LinearRegression()

# %%
print(y_pred)
# Out:
# 0      8.03
# 1      8.00
# 2      8.00
# 3      8.60
# 4      7.90
#        ...
# 668    7.40
# 669    7.20
# 670    7.20
# 671    7.40
# 672    7.30
# Name: pH Max, Length: 631, dtype: float64

# %%
k.dropna()
# Out:
#      Station Code  Temperature Min  Temperature Max  pH Min  pH Max  \
# 0            26.0             22.0             26.0    7.51    8.03
# 1          1513.0             23.0             26.0    7.70    8.00
# 2          1514.0             23.0             23.0    7.40    8.00
# 4          1517.0             23.0             29.0    7.60    7.90
# 5          1518.0             22.0             28.0    7.70    7.90
# ..            ...              ...              ...     ...     ...
# 668        1602.0             29.7             31.6    7.10    7.40
# 669        1603.0             29.8             31.4    7.20    7.20
# 670        1604.0             30.1             31.3    7.10    7.20
# 671        1605.0             30.2             31.3    7.20    7.40
# 672        1606.0             29.6             31.5    7.10    7.30
#
#      Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 0                          960.0                       1418.0  2016
# ...

# %%
# Separate features and target
X = k.drop(['Station Code'], axis=1)
y = k['pH Max']

# %%
X.dropna()
# Out:
#      Temperature Min  Temperature Max  pH Min  pH Max  \
# 0               22.0             26.0    7.51    8.03
# 1               23.0             26.0    7.70    8.00
# 2               23.0             23.0    7.40    8.00
# 4               23.0             29.0    7.60    7.90
# 5               22.0             28.0    7.70    7.90
# ..               ...              ...     ...     ...
# 668             29.7             31.6    7.10    7.40
# 669             29.8             31.4    7.20    7.20
# 670             30.1             31.3    7.10    7.20
# 671             30.2             31.3    7.20    7.40
# 672             29.6             31.5    7.10    7.30
#
#      Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 0                          960.0                       1418.0  2016
# 1                         1214.0                       1260.0  2016
# 2                         1010.0                       1427.0  2016
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#      Temperature Min  Temperature Max  pH Min  pH Max  \
# 580             28.0             30.0     7.0     7.9
# 654             27.0             28.0     6.9     7.6
# 521             26.5             28.0     7.5     7.8
# 203             27.0             28.0     7.9     8.3
# 196             29.0             29.0     7.3     7.3
# ..               ...              ...     ...     ...
# 71              26.0             29.0     7.2     7.4
# 106             28.0             28.0     7.3     7.3
# 270             25.0             25.0     7.9     8.0
# 435             24.0             28.0     7.1     7.5
# 102             22.0             27.0     7.3     7.6
#
#      Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 580                        813.1                       3560.0  2016
# 654                         59.0                        101.0  2016
# 521                       1295.0                       1330.0  2016
# ...

# %%
y_train
# Out:
# 580    7.9
# 654    7.6
# 521    7.8
# 203    8.3
# 196    7.3
#       ...
# 71     7.4
# 106    7.3
# 270    8.0
# 435    7.5
# 102    7.6
# Name: pH Max, Length: 450, dtype: float64

# %%
X_train.dropna(inplace=True)
y_train = y_train[X_train.index]

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy="mean")
X_test = imputer.fit_transform(X_test)

# %%
model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8.3       , 7.6       , 8.        , 7.6       , 7.7       ,
#        7.2       , 7.6       , 8.        , 7.6       , 8.2       ,
#        7.8       , 7.8       , 7.9       , 8.        , 7.3       ,
#        7.5       , 7.6       , 7.8       , 7.3       , 8.4       ,
#        8.1       , 7.2       , 8.2       , 8.        , 7.4       ,
#        7.8       , 7.1       , 7.9       , 7.7       , 7.5       ,
#        7.4       , 9.6       , 8.6       , 8.        , 7.4       ,
#        7.6       , 7.6       , 7.8       , 7.4       , 7.8       ,
#        8.3       , 9.        , 7.4       , 7.2       , 7.5       ,
#        7.2       , 7.7       , 7.5       , 8.4       , 7.8       ,
#        7.3       , 5.8       , 7.4       , 8.        , 7.7       ,
# ...

# %%
#deploy the model
import pickle

# Save the trained model to a file
with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

# Load the trained model from the file
with open('model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Use the loaded model to make predictions
y_pred = loaded_model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
